# %% [markdown]
# ### DLP Lab5
# Goal of this lab is to to implement a conditional seq2seq VAE for English tense conversion
# 1. Tense conversion: ‘access’ to ‘accessing’, or ‘accessed’ to ‘accesses’
# 2. Generative model: Gaussian noise + tense -> access, accesses, accessing, accessed
#
# #### Requirment
# 1. Implement a conditional seq2seq VAE.
#     * Modify encoder, decoder, and training functions
#     * Implement evaluation function, dataloader, and reparameterization trick.
# 2. Plot and **compare** the CrossEntropy loss, KL loss and BLEU-4 score of testing data curves during training with different settings of your model
#     * Teacher forcing ratio
#     * KL annealing schedules (two methods)
# 3. Output the conversion results between tenses (from tense A to tense B)
# 4. Output the results generated by a Gaussian noise with 4 tenses.
#
# #### Implement detail
# 1. Use LSTM
# 2. Log variance
# 3. Condition (tense)
#     * Simply concatenate to the hidden_0 and z
#     * Embed your condition to high dimensional space (or simply use one-hot)
# 4. KL lost annealing
#     * Monotonic
#     * Cyclical
# 5. Adopt BLEU-4 score function in NLTK (average 10 testing scores)
# 6. Adopt Gaussian_score() to compute the generation score
#     * Random sample 100 noise to generate 100 words with 4 different tenses(totally 400 words)
#     * 4 words should exactly match the training data
#
# #### Hyper parameters
# * LSTM hidden size: 256 or 512
# * Latent size: 32
# * Condition embedding size: 8
# * Teacher forcing ratio: 0~1 (>0.5) (???
# * KL weight: 0~1 (???
# * Learning rate: 0.05
# * Optimizer: SGD
# * Loss function: torch.nn.CrossEntropyLoss()
#
# Date: 2020/05/

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import time
import math
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.utils import data
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np
import pandas as pd
from os import system
from nltk.translate.bleu_score import SmoothingFunction, sentence_bleu

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SOS_token = 0
EOS_token = 1
#----------Hyper Parameters----------#
hidden_size = 256
condition_size = 8
#The number of vocabulary
vocab_size = 30
teacher_forcing_ratio = 1.0
empty_input_ratio = 0.1
KLD_weight = 0.0
learning_rate = 0.05

# %%
def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %2ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# ### Fetch data
# * train.txt: Each training pair includes 4 words: simple present(sp), third person(tp), present progressive(pg), simple past(p)
# * test.txt: Each training pair includes 2 words with different combination of tenses

# %%
def getData(mode):
    assert mode == 'train' or mode == 'test'
    if mode == 'train':
        data = pd.read_csv('./data/'+mode+'.txt', delimiter=' ', header=None)
    else:
        data = []
        with open('./data/test.txt','r') as fp:
            for line in fp:
                word = line.split(' ')
                word[1] = word[1].strip('\n')
                data.extend([word])
    return data

getData("train")
# Out:
#                0            1             2            3
# 0        abandon     abandons    abandoning    abandoned
# 1           abet        abets      abetting      abetted
# 2       abdicate    abdicates    abdicating    abdicated
# 3         abduct      abducts     abducting     abducted
# 4         abound      abounds     abounding     abounded
# ...          ...          ...           ...          ...
# 1222      exhort      exhorts     exhorting     exhorted
# 1223  exhilarate  exhilarates  exhilarating  exhilarated
# 1224   exculpate   exculpates   exculpating   exculpated
# 1225  exasperate  exasperates  exasperating  exasperated
# 1226  exacerbate  exacerbates  exacerbating  exacerbated
#
# [1227 rows x 4 columns]

# %% [markdown]
# #### Vocabulary

# %%
class Vocabuary():
    def __init__(self):
        self.word2index = {'SOS': 0, 'EOS': 1, 'PAD': 2, 'UNK': 3}
        self.index2word = {0: 'SOS', 1: 'EOS', 2: 'PAD', 3: 'UNK'}
        self.n_words = 4
        self.max_length = 0
        self.build_vocab(getData('train'))
        

    # input the training data and build vocabulary
    def build_vocab(self, corpus):        
        for idx in range(corpus.shape[0]):
            for word in corpus.iloc[idx,:]:
                if len(word) > self.max_length:
                    self.max_length = len(word)
                    
                for char in word:
                    if char not in self.word2index:
                        self.word2index[char] = self.n_words
                        self.index2word[self.n_words] = char
                        self.n_words += 1                      
                    
    # convert word in indices
    def word2indices(self, word, add_eos=False, add_sos=False):
        indices = [self.word2index[char] if char in self.word2index else 3 for char in word]

        if add_sos:
            indices.insert(0, 0)
        if add_eos:
            indices.append(1)
            
        # padding input of same target into same length
        indices.extend([2]*(self.max_length-len(word)))
            
        return np.array(indices)
    
    # convert indices to word
    def indices2word(self, indices):
        word = [self.index2word[idx] for idx in indices if idx > 2 ]
        return ''.join(word)

# %%
v = Vocabuary()
t = "exculpated"
idx = v.word2indices(t)
print(idx)
t = v.indices2word(idx)
print(t)
# Out:
# [12 29 14 15 20 17  4 13 12  7  2  2  2  2  2]
# exculpated

# %% [markdown]
# #### DataLoader

# %%
class TenseLoader(data.Dataset):
    def __init__(self, mode, vocab):
        self.mode = mode   
        self.vocab = vocab
        self.order = {'sp':0, 'tp':1, 'pg':2, 'p':3}
        self.build_pair()
        
    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        if self.mode == 'train':
            input_tense = self.data[index][0][0]
            input_tensor = torch.tensor(self.vocab.word2indices(self.data[index][0][1]))
            target_tense = self.data[index][1][0]
            target_tensor = torch.tensor(self.vocab.word2indices(self.data[index][1][1]))    

        else:
            condition = [["sp", "p"], ["sp", "pg"], ["sp", "tp"], ["sp", "tp"], ["p", "tp"], 
                        ["sp", "pg"], ["p", "sp"], ["pg", "sp"], ["pg", "p"], ["pg", "tp"]]
            input_tense = self.order[condition[index][0]]
            input_tensor = torch.tensor(self.vocab.word2indices(self.data[index][0]))
            target_tense = self.order[condition[index][1]]
            target_tensor = torch.tensor(self.vocab.word2indices(self.data[index][1]))

        return (input_tense, input_tensor), (target_tense, target_tensor)
        
    def build_pair(self):
        if self.mode == 'train':
            pd = getData(self.mode)
            self.data = []
            for index in range(len(pd)):
                for i in range(4):
                    for j in range(4):
                        self.data.append([(i, pd.iloc[index,:][i]), (j, pd.iloc[index,:][j])])
        else:
            self.data = getData(self.mode)

# %%
trainset = TenseLoader('train', v)
trainset[1]
# Out:
# ((0, tensor([4, 5, 4, 6, 7, 8, 6, 2, 2, 2, 2, 2, 2, 2, 2])),
#  (1, tensor([4, 5, 4, 6, 7, 8, 6, 9, 2, 2, 2, 2, 2, 2, 2])))

# %%
testset = TenseLoader('test', v)
testset[0]
# Out:
# ((0, tensor([4, 5, 4, 6, 7, 8, 6, 2, 2, 2, 2, 2, 2, 2, 2])),
#  (3, tensor([ 4,  5,  4,  6,  7,  8,  6, 12,  7,  2,  2,  2,  2,  2,  2])))

# %% [markdown]
# #### Show reslut
# * Crossentropy loss curve
# * KL loss curve
# * BLEU-4 score curve

# %%
def show_result(score, c_loss, kl_loss):  
    label = ["BLEU Score", "Crossentropy Loss", "KL Loss"]
    
    plt.figure(figsize=(10, 6))
    
    plt.ylabel("Loss & Score")
    plt.xlabel("Epochs")
    plt.title("Training Curve", fontsize=18)
    plt.plot(score, label="BLEU Score")
    plt.plot(c_loss, label="Crossentropy Loss")
    plt.plot(kl_loss, label="KL Loss")

    plt.show()

# %% [markdown]
# #### Condition
# concatenate the condition part with the initial hidden part
# * nn.Embedding
# * One-hot

# %%
def condition_embedding(condition_size, condition):
    embedding = nn.Embedding(4, condition_size)
    
    if type(condition) == int:
        condition_tensor = torch.tensor(condition)
        embedded_tense = embedding(condition_tensor).view(1, -1)
    else: 
        condition_tensor = torch.tensor(condition)
        embedded_tense = embedding(condition_tensor)
        
    return embedded_tense
                     
condition_embedding(condition_size, 2)
# Out:
# tensor([[ 1.0307, -0.8062, -1.6080,  1.0490,  0.2623,  0.4760,  1.3073, -0.1252]],
#        grad_fn=<ViewBackward>)

# %% [markdown]
# ### Evaluation

# %%
#compute BLEU-4 score
def compute_bleu(output, reference):
    """
    reference = 'accessed'
    output = 'access'
    return BLEU score
    """
    cc = SmoothingFunction()
    if len(reference) == 3:
        weights = (0.33,0.33,0.33)
    else:
        weights = (0.25,0.25,0.25,0.25)
    return sentence_bleu([reference], output,weights=weights,smoothing_function=cc.method1)

# %%
# compute generation score
def Gaussian_score(predictions, plot_pred=False):
    """
    the order should be : simple present, third person, present progressive, past
    predictions = [['consult', 'consults', 'consulting', 'consulted'],...]
    return Gaussian_score score
    """
    score = 0
    words_list = []
    with open('./data/train.txt','r') as fp:
        for line in fp:
            word = line.split(' ')
            word[3] = word[3].strip('\n')
            words_list.extend([word])
        for idx, t in enumerate(predictions):
            if plot_pred:
                print (t)
            for idxj, i in enumerate(words_list):
                if t == i:
                    score += 1
    return score/len(predictions)

# %%
# print the prediction and return the bleu score
def BLEU_score(prediction, plot_pred=False):
    data = getData('test')
    inputs = data[0]
    targets = data[1]

    bleu_total = 0
    for idx in range(len(inputs)):
        bleu_total += compute_bleu(prediction[idx], targets[idx])

        if plot_pred:
            output = "\ninput:  {}\ntarget: {}\npred:   {}".format(inputs[idx], targets[idx], prediction[idx])
            print ("="*30+output)

    return bleu_total/len(inputs)

# %%
def predict(encoder, decoder, vocab, dataloader, batch_size=64, plot_pred=False):    
    prediction = []
    inputs = []
    outputs = []

    with torch.no_grad():    
        for input_data, target_data in dataloader:
            input_tense = input_data[0]
            input_tensors = input_data[1].to(device)
            target_tense = target_data[0]
            target_tensors = target_data[1].to(device)
            
            batch_size = input_tensors.size(0)

            # transpose tensor from (batch_size, seq_len) to (seq_len, batch_size)
            input_tensors = input_tensors.transpose(0, 1)
            target_tensors = target_tensors.transpose(0, 1)
        
            # record outputs
            output_tensors = torch.zeros(input_tensors.size())

            # get tense embedding tensor
            input_embedded = condition_embedding(condition_size, input_tense)
            target_embedded = condition_embedding(condition_size, target_tense)
        
            # init hidden state and cat condition
            encoder_hidden = encoder.initHidden(input_embedded, batch_size)

            # calculate number of time step
            input_length = input_tensors.size(0)
            target_length = target_tensors.size(0)

            #----------sequence to sequence part for encoder----------#
            for ei in range(input_length):
                encoder_output, encoder_hidden = encoder(
                    input_tensors[ei], encoder_hidden)

            decoder_input = torch.tensor([[SOS_token] for i in range(batch_size)], device=device)
            output = torch.zeros(input_length, batch_size)

            # reparameterization trick
            mu, logvar = encoder.variational(encoder_hidden)
            reparameterized_state = reparameterize(mu, logvar)

            # init decoder hidden state and cat condition
            decoder_hidden = decoder.initHidden(reparameterized_state, target_embedded, batch_size)

            #----------sequence to sequence part for decoder----------#
            for di in range(target_length):
                decoder_output, decoder_hidden = decoder(
                    decoder_input, decoder_hidden) 
                topv, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze().detach()  # detach from history as input
                output[di] = decoder_input

            # get predict indices
            output = output.transpose(0, 1) 

            # convert input into string
            for idx in range(batch_size):
                outputs.append(vocab.indices2word(output[idx].data.numpy()))

    return outputs

# %%
def evaluate(encoder, decoder, vocab, batch_size=64, plot_pred=False):
    # predict train.txt for gaussian score
    # create dataloader
    trainset = TenseLoader('train', vocab)
    trainloader = data.DataLoader(trainset, batch_size=batch_size)
    predictions = predict(encoder, decoder, vocab, dataloader=trainloader, batch_size=batch_size, plot_pred=plot_pred)
    
    # compute Gaussian score
    gaussian_score = Gaussian_score(predictions, plot_pred=plot_pred)
    if plot_pred:
        print ("Gaussian score: %.2f"%gaussian_score)

    # predict test.txt for bleu score
    testset = TenseLoader('test', vocab)
    testloader = data.DataLoader(testset, batch_size=batch_size)
    predictions = predict(encoder, decoder, vocab, dataloader=testloader, batch_size=batch_size, plot_pred=plot_pred)
      
    # compute BLEU score
    bleu_score = BLEU_score(predictions, plot_pred=plot_pred)
    if plot_pred:
        print ("BLEU score: %.2f"%bleu_score)
    
    return bleu_score, gaussian_score

# %% [markdown]
# #### Reparameterization Trick

# %%
def reparameterize(mu, logvar):
    std = torch.exp(0.5*logvar)
    eps = torch.randn_like(std)
    return mu + eps*std

# %% [markdown]
# ### Encoder

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, condition_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.condition_size = condition_size
        
        self.fc1 = nn.Linear(hidden_size+condition_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size+condition_size, hidden_size)

        self.embedding = nn.Embedding(input_size, hidden_size+condition_size)
        self.lstm = nn.LSTM(hidden_size+condition_size, hidden_size+condition_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, -1, self.hidden_size+condition_size)
        output = embedded
        output, hidden = self.lstm(output, hidden)
        return output, hidden
    
    def variational(self, hidden):
        return self.fc1(hidden[0]), self.fc2(hidden[0])

    def initHidden(self, embedded_tense, batch_size=64):
        embedded_tense = embedded_tense.to(device).view(1, batch_size, -1)
        zeros = torch.zeros(1, batch_size, self.hidden_size, device=device)
        return (torch.cat((zeros, embedded_tense), 2),
                torch.cat((zeros, embedded_tense), 2))

# %% [markdown]
# ### Decoder

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, condition_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.condition_size = condition_size

        self.embedding = nn.Embedding(output_size, hidden_size+condition_size)
        self.lstm = nn.LSTM(hidden_size+condition_size, hidden_size+condition_size)
        self.out = nn.Linear(hidden_size+condition_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, -1, self.hidden_size+condition_size)
        output = F.relu(output)
        output, hidden = self.lstm(output, hidden)
        output = self.out(output[0])
        return output, hidden

    def initHidden(self, hidden_state, embedded_tense, batch_size):
        embedded_tense = embedded_tense.to(device).view(1, batch_size, -1)
        return (torch.cat((hidden_state, embedded_tense), 2),
                torch.cat((hidden_state, embedded_tense), 2))

# %% [markdown]
# ### Train
# * Use teacher forcing
# * Use KL loss annealing

# %%
def kl_annealing(epochs, mode):
    assert mode == "monotonic" or mode == "cyclical"
    if mode == "monotonic":
        if epochs > 1e4:
            KLD_weight = 1
        else:
            KLD_weight = 1e-4 * epochs
    else:
        if epochs%1e4 > 5e3:
            KLD_weight = 1
        else:
            KLD_weight = 2e-1 * epochs
    return KLD_weight

# %%
def compute_kl_loss(mu, logvar):
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return KLD

# %%
# save model every epoch
def train(input_tensors, input_tense, target_tensors, target_tense, encoder, decoder, encoder_optimizer, decoder_optimizer, 
          criterion, epochs, teacher_forcing_ratio):
    batch_size = input_tensors.size(0)
    # get tense embedding tensor
    input_embedded = condition_embedding(condition_size, input_tense)
    target_embedded = condition_embedding(condition_size, target_tense)

    # transpose tensor from (batch_size, seq_len) to (seq_len, batch_size)
    input_tensors = input_tensors.transpose(0, 1)
    target_tensors = target_tensors.transpose(0, 1)

    # init encoder hidden state and cat conditionde
    encoder_hidden = encoder.initHidden(input_embedded, batch_size)

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # calculate number of time step
    input_length = input_tensors.size(0)
    target_length = target_tensors.size(0)

    loss = 0
    ce_loss = 0

    #----------sequence to sequence part for encoder----------#
    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensors[ei], encoder_hidden)

    # reparameterization trick
    mu, logvar = encoder.variational(encoder_hidden)
    reparameterized_state = reparameterize(mu, logvar)

    # calculate kl loss
    kl_loss = kl_annealing(epochs, "monotonic") * compute_kl_loss(mu, logvar) / batch_size
    loss += kl_loss

    # init decoder hidden state and cat condition
    decoder_hidden = decoder.initHidden(reparameterized_state, target_embedded, batch_size)

    decoder_input = torch.tensor([[SOS_token] for i in range(batch_size)], device=device)

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    #----------sequence to sequence part for decoder----------#
    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden) 
            ce_loss += criterion(decoder_output, target_tensors[di])
            decoder_input = target_tensors[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden) 
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            ce_loss += criterion(decoder_output, target_tensors[di])

    loss += ce_loss
    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return ce_loss.item()/target_length, kl_loss

# %%
def trainIters(encoder, decoder, vocab, n_iters, print_every=1000, plot_every=100, 
               batch_size=64, learning_rate=0.01, teacher_forcing_ratio=1.0):
    start = time.time()

    # Reset every print_every, for print log
    print_ce_loss_total = 0  
    print_kl_loss_total = 0
    # Reset every plot_every, for plot curve
    crossentropy_losses = []
    kl_losses = []
    plot_ce_loss_total = 0
    plot_kl_loss_total = 0
    # scores
    gaussian_scores = []
    bleu_scores = []
    

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)

    # create dataloader
    trainset = TenseLoader('train', vocab)
    trainloader = data.DataLoader(trainset, batch_size, shuffle = True)

    criterion = nn.CrossEntropyLoss()

    for iter in range(1, n_iters + 1):
        for input_data, target_data in trainloader:
            input_tense = input_data[0]
            input_tensors = input_data[1].to(device)
            target_tense = target_data[0]
            target_tensors = target_data[1].to(device)

            ce_loss, kl_loss = train(input_tensors, input_tense, target_tensors, target_tense, encoder, decoder, 
                                     encoder_optimizer, decoder_optimizer, criterion, (iter-1), teacher_forcing_ratio)
            print_ce_loss_total += ce_loss
            print_kl_loss_total += kl_loss
            plot_ce_loss_total += ce_loss
            plot_kl_loss_total += kl_loss
            
        # evaluate and save model
        _, gaussian_score = evaluate(encoder, decoder, vocab, plot_pred=False)
        gaussian_scores.append(gaussian_score)
#         if avg_bleu > max_score:
#             max_score = avg_bleu
#             print ("Model save...")
#             torch.save(encoder, "./models/encoder_{:.4f}.ckpt".format(avg_bleu))
#             torch.save(decoder, "./models/decoder_{:.4f}.ckpt".format(avg_bleu))

        if iter % print_every == 0:
            print_ce_loss_avg = print_ce_loss_total / print_every
            print_kl_loss_avg = print_kl_loss_total / print_every
            print('%s (%d %2d%%) CE Loss: %.4f, KL Loss: %.4f, Gaussian score: %.2f' % 
                  (timeSince(start, iter / n_iters), iter, iter / n_iters * 100, print_ce_loss_avg, print_kl_loss_avg, gaussian_score))
            print_ce_loss_total = 0
            print_kl_loss_total = 0

        crossentropy_losses.append(plot_ce_loss_total)
        plot_ce_loss_total = 0
        kl_losses.append(plot_kl_loss_total)
        plot_kl_loss_total = 0
            
#     print ("The highest score is %s"%max_score)
            
    return gaussian_scores, crossentropy_losses

# %%
encoder1 = EncoderRNN(vocab_size, hidden_size, condition_size).to(device)
decoder1 = DecoderRNN(hidden_size, vocab_size, condition_size).to(device)
vocab = Vocabuary()
gaussian_scores, crossentropy_losses = trainIters(encoder1, decoder1, vocab, 100, print_every=1, plot_every=1, teacher_forcing_ratio=0.8)
# show_result(scores, losses)
# Out:
# /home/user/anaconda3/envs/th1.2/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 0m 18s (- 30m 21s) (1  1%) CE Loss: 496.8858, KL Loss: 0.0000, Gaussian score: 0.00
# 0m 32s (- 26m 44s) (2  2%) CE Loss: 429.5147, KL Loss: 78.4589, Gaussian score: 0.00
# 0m 46s (- 25m 13s) (3  3%) CE Loss: 402.5837, KL Loss: 231.3072, Gaussian score: 0.00
# 1m  1s (- 24m 25s) (4  4%) CE Loss: 400.0578, KL Loss: 445.1276, Gaussian score: 0.00
# 1m 15s (- 23m 51s) (5  5%) CE Loss: 394.6223, KL Loss: 729.0020, Gaussian score: 0.00
# 1m 29s (- 23m 21s) (6  6%) CE Loss: 391.6205, KL Loss: 1075.7430, Gaussian score: 0.00
# 1m 43s (- 22m 56s) (7  7%) CE Loss: 382.6861, KL Loss: 1441.0710, Gaussian score: 0.00
# 1m 57s (- 22m 34s) (8  8%) CE Loss: 374.8272, KL Loss: 1840.8333, Gaussian score: 0.00
# 2m 11s (- 22m 13s) (9  9%) CE Loss: 369.3593, KL Loss: 2396.2534, Gaussian score: 0.00
# 2m 25s (- 21m 53s) (10 10%) CE Loss: 359.0015, KL Loss: 3046.0583, Gaussian score: 0.00
# 2m 40s (- 21m 35s) (11 11%) CE Loss: 348.5397, KL Loss: 3729.3750, Gaussian score: 0.00
# 2m 54s (- 21m 18s) (12 12%) CE Loss: 341.7385, KL Loss: 4414.3604, Gaussian score: 0.00
# 3m  8s (- 21m  0s) (13 13%) CE Loss: 333.4395, KL Loss: 5078.3198, Gaussian score: 0.00
# 3m 22s (- 20m 43s) (14 14%) CE Loss: 331.2377, KL Loss: 5710.7432, Gaussian score: 0.00
# 3m 36s (- 20m 28s) (15 15%) CE Loss: 323.8449, KL Loss: 6287.5322, Gaussian score: 0.00
# 3m 50s (- 20m 12s) (16 16%) CE Loss: 311.8861, KL Loss: 6829.2832, Gaussian score: 0.00
# 4m  4s (- 19m 55s) (17 17%) CE Loss: 321.5247, KL Loss: 7196.8506, Gaussian score: 0.00
# 4m 18s (- 19m 39s) (18 18%) CE Loss: 304.0509, KL Loss: 7369.8770, Gaussian score: 0.00
# 4m 32s (- 19m 23s) (19 19%) CE Loss: 296.8331, KL Loss: 7609.7822, Gaussian score: 0.00
# 4m 47s (- 19m  9s) (20 20%) CE Loss: 306.3574, KL Loss: 7824.9609, Gaussian score: 0.00
# 5m  1s (- 18m 54s) (21 21%) CE Loss: 283.3109, KL Loss: 7976.9170, Gaussian score: 0.00
# 5m 15s (- 18m 38s) (22 22%) CE Loss: 284.1207, KL Loss: 8246.0771, Gaussian score: 0.00
# 5m 29s (- 18m 22s) (23 23%) CE Loss: 270.6567, KL Loss: 8427.9766, Gaussian score: 0.00
# 5m 43s (- 18m  6s) (24 24%) CE Loss: 280.2836, KL Loss: 8602.3965, Gaussian score: 0.00
# 5m 57s (- 17m 51s) (25 25%) CE Loss: 265.8324, KL Loss: 8692.6943, Gaussian score: 0.00
# 6m 10s (- 17m 35s) (26 26%) CE Loss: 262.7109, KL Loss: 8941.6133, Gaussian score: 0.00
# 6m 25s (- 17m 20s) (27 27%) CE Loss: 257.0697, KL Loss: 9150.6846, Gaussian score: 0.00
# 6m 39s (- 17m  7s) (28 28%) CE Loss: 241.1324, KL Loss: 9444.2998, Gaussian score: 0.00
# 6m 54s (- 16m 53s) (29 28%) CE Loss: 236.5782, KL Loss: 9765.3340, Gaussian score: 0.00
# 7m  8s (- 16m 39s) (30 30%) CE Loss: 221.5175, KL Loss: 10228.2900, Gaussian score: 0.00
# 7m 22s (- 16m 25s) (31 31%) CE Loss: 221.1352, KL Loss: 10751.2793, Gaussian score: 0.00
# 7m 36s (- 16m 10s) (32 32%) CE Loss: 210.4831, KL Loss: 11382.8516, Gaussian score: 0.00
# 7m 50s (- 15m 55s) (33 33%) CE Loss: 192.9924, KL Loss: 12004.0039, Gaussian score: 0.00
# 8m  4s (- 15m 41s) (34 34%) CE Loss: 184.2158, KL Loss: 12770.7793, Gaussian score: 0.00
# 8m 19s (- 15m 26s) (35 35%) CE Loss: 158.8098, KL Loss: 13679.7441, Gaussian score: 0.00
# 8m 33s (- 15m 12s) (36 36%) CE Loss: 143.8828, KL Loss: 14551.9512, Gaussian score: 0.00
# 8m 47s (- 14m 58s) (37 37%) CE Loss: 141.0974, KL Loss: 15351.5498, Gaussian score: 0.00
# 9m  1s (- 14m 44s) (38 38%) CE Loss: 126.6262, KL Loss: 16119.9072, Gaussian score: 0.00
# 9m 15s (- 14m 29s) (39 39%) CE Loss: 104.3227, KL Loss: 16714.3770, Gaussian score: 0.00
# 9m 30s (- 14m 15s) (40 40%) CE Loss: 97.3221, KL Loss: 17306.0918, Gaussian score: 0.00
# 9m 44s (- 14m  1s) (41 41%) CE Loss: 90.1960, KL Loss: 17710.0000, Gaussian score: 0.00
# 9m 58s (- 13m 47s) (42 42%) CE Loss: 81.0377, KL Loss: 18065.4648, Gaussian score: 0.00
# 10m 13s (- 13m 32s) (43 43%) CE Loss: 78.3325, KL Loss: 18231.0020, Gaussian score: 0.00
# 10m 27s (- 13m 18s) (44 44%) CE Loss: 68.5746, KL Loss: 18352.8086, Gaussian score: 0.00
# 10m 41s (- 13m  4s) (45 45%) CE Loss: 64.4251, KL Loss: 18316.2734, Gaussian score: 0.00
# 10m 55s (- 12m 49s) (46 46%) CE Loss: 67.5384, KL Loss: 18319.1094, Gaussian score: 0.00
# 11m  9s (- 12m 34s) (47 47%) CE Loss: 62.8228, KL Loss: 18202.8730, Gaussian score: 0.00
# 11m 23s (- 12m 20s) (48 48%) CE Loss: 61.5298, KL Loss: 18011.8281, Gaussian score: 0.00
# 11m 38s (- 12m  6s) (49 49%) CE Loss: 58.4982, KL Loss: 17857.1270, Gaussian score: 0.00
# 11m 52s (- 11m 52s) (50 50%) CE Loss: 58.8772, KL Loss: 17722.7715, Gaussian score: 0.00
# 12m  6s (- 11m 38s) (51 51%) CE Loss: 56.6619, KL Loss: 17492.3691, Gaussian score: 0.00
# 12m 20s (- 11m 23s) (52 52%) CE Loss: 58.8859, KL Loss: 17204.6055, Gaussian score: 0.00
# 12m 35s (- 11m  9s) (53 53%) CE Loss: 58.3634, KL Loss: 16979.6523, Gaussian score: 0.00
# 12m 49s (- 10m 55s) (54 54%) CE Loss: 58.6060, KL Loss: 16793.8320, Gaussian score: 0.00
# 13m  3s (- 10m 41s) (55 55%) CE Loss: 55.8954, KL Loss: 16592.7852, Gaussian score: 0.00
# 13m 18s (- 10m 27s) (56 56%) CE Loss: 55.0512, KL Loss: 16451.2422, Gaussian score: 0.00
# 13m 32s (- 10m 12s) (57 56%) CE Loss: 50.8058, KL Loss: 16177.4541, Gaussian score: 0.00
# 13m 46s (- 9m 58s) (58 57%) CE Loss: 59.3182, KL Loss: 16221.2227, Gaussian score: 0.00
# 14m  1s (- 9m 44s) (59 59%) CE Loss: 53.0342, KL Loss: 15856.4912, Gaussian score: 0.00
# 14m 15s (- 9m 30s) (60 60%) CE Loss: 54.5106, KL Loss: 15557.7109, Gaussian score: 0.00
# 14m 29s (- 9m 15s) (61 61%) CE Loss: 52.7510, KL Loss: 15417.6855, Gaussian score: 0.00
# 14m 43s (- 9m  1s) (62 62%) CE Loss: 51.2110, KL Loss: 15280.9297, Gaussian score: 0.00
# 14m 58s (- 8m 47s) (63 63%) CE Loss: 52.4230, KL Loss: 15148.4961, Gaussian score: 0.00
# 15m 12s (- 8m 33s) (64 64%) CE Loss: 52.4914, KL Loss: 14978.7471, Gaussian score: 0.00
# 15m 26s (- 8m 18s) (65 65%) CE Loss: 53.1529, KL Loss: 14851.2568, Gaussian score: 0.00
# 15m 40s (- 8m  4s) (66 66%) CE Loss: 51.9997, KL Loss: 14681.8398, Gaussian score: 0.00
# 15m 54s (- 7m 50s) (67 67%) CE Loss: 50.5426, KL Loss: 14594.7920, Gaussian score: 0.00
# 16m  8s (- 7m 35s) (68 68%) CE Loss: 52.8498, KL Loss: 14463.5879, Gaussian score: 0.00
# 16m 21s (- 7m 21s) (69 69%) CE Loss: 51.3059, KL Loss: 14343.9854, Gaussian score: 0.00
# 16m 36s (- 7m  6s) (70 70%) CE Loss: 50.7617, KL Loss: 14239.3623, Gaussian score: 0.00
# 16m 51s (- 6m 52s) (71 71%) CE Loss: 53.3860, KL Loss: 14131.8457, Gaussian score: 0.00
# 17m  6s (- 6m 39s) (72 72%) CE Loss: 59.4741, KL Loss: 14320.9775, Gaussian score: 0.00
# 17m 21s (- 6m 25s) (73 73%) CE Loss: 48.3284, KL Loss: 14074.6768, Gaussian score: 0.00
# 17m 36s (- 6m 11s) (74 74%) CE Loss: 53.8815, KL Loss: 13824.2666, Gaussian score: 0.00
# 17m 50s (- 5m 56s) (75 75%) CE Loss: 52.7329, KL Loss: 13725.1221, Gaussian score: 0.00
# 18m  5s (- 5m 42s) (76 76%) CE Loss: 50.8605, KL Loss: 13631.3857, Gaussian score: 0.00
# 18m 19s (- 5m 28s) (77 77%) CE Loss: 51.4846, KL Loss: 13558.4209, Gaussian score: 0.00
# 18m 33s (- 5m 14s) (78 78%) CE Loss: 51.4682, KL Loss: 13519.7725, Gaussian score: 0.00
# 18m 48s (- 4m 59s) (79 79%) CE Loss: 51.1859, KL Loss: 13428.0830, Gaussian score: 0.00
# 19m  2s (- 4m 45s) (80 80%) CE Loss: 50.7273, KL Loss: 13274.8633, Gaussian score: 0.00
# 19m 16s (- 4m 31s) (81 81%) CE Loss: 51.7637, KL Loss: 13226.2666, Gaussian score: 0.00
# 19m 30s (- 4m 17s) (82 82%) CE Loss: 51.4049, KL Loss: 13207.3799, Gaussian score: 0.00
# 19m 45s (- 4m  2s) (83 83%) CE Loss: 51.2192, KL Loss: 13142.3057, Gaussian score: 0.00
# 19m 59s (- 3m 48s) (84 84%) CE Loss: 49.9302, KL Loss: 13055.7979, Gaussian score: 0.00
# 20m 14s (- 3m 34s) (85 85%) CE Loss: 50.3192, KL Loss: 13031.0186, Gaussian score: 0.00
# 20m 29s (- 3m 20s) (86 86%) CE Loss: 49.9188, KL Loss: 12937.8652, Gaussian score: 0.00
# 20m 43s (- 3m  5s) (87 87%) CE Loss: 47.3073, KL Loss: 12851.7090, Gaussian score: 0.00
# 20m 57s (- 2m 51s) (88 88%) CE Loss: 51.8411, KL Loss: 12844.1797, Gaussian score: 0.00
# 21m 12s (- 2m 37s) (89 89%) CE Loss: 51.8871, KL Loss: 12785.4893, Gaussian score: 0.00
# 21m 27s (- 2m 23s) (90 90%) CE Loss: 49.1069, KL Loss: 12767.7871, Gaussian score: 0.00
# 21m 41s (- 2m  8s) (91 91%) CE Loss: 52.1761, KL Loss: 12660.0156, Gaussian score: 0.00
# 21m 55s (- 1m 54s) (92 92%) CE Loss: 50.8591, KL Loss: 12621.7246, Gaussian score: 0.00
# 22m 10s (- 1m 40s) (93 93%) CE Loss: 48.7528, KL Loss: 12565.9297, Gaussian score: 0.00
# 22m 24s (- 1m 25s) (94 94%) CE Loss: 47.5822, KL Loss: 12498.9170, Gaussian score: 0.00
# 22m 39s (- 1m 11s) (95 95%) CE Loss: 48.0914, KL Loss: 12440.6172, Gaussian score: 0.00
# 22m 53s (- 0m 57s) (96 96%) CE Loss: 48.1637, KL Loss: 12424.8047, Gaussian score: 0.00
# 23m  8s (- 0m 42s) (97 97%) CE Loss: 49.4416, KL Loss: 12404.8643, Gaussian score: 0.00
# 23m 22s (- 0m 28s) (98 98%) CE Loss: 51.6383, KL Loss: 12339.0947, Gaussian score: 0.00
# 23m 36s (- 0m 14s) (99 99%) CE Loss: 50.3529, KL Loss: 12247.1309, Gaussian score: 0.00
# 23m 50s (- 0m  0s) (100 100%) CE Loss: 48.6790, KL Loss: 12234.2744, Gaussian score: 0.00

# %%
bleu, gaussian = evaluate(encoder1, decoder1, vocab, batch_size=64, plot_pred=True)
# Out:
# /home/user/anaconda3/envs/th1.2/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# abandon
# abandon
# abandoning
# abandons
# abandoning
# abandons
# abandons
# abandoning
# abandoned
# abandons
# abandons
# abandons
# abandoning
# abandoned
# abandoning
# abandoned
# abet
# abet
# abetting
# abetting
# abets
# abetting
# abetting
# abetting
# abetting
# abetting
# abetting
# abetting
# abetting
# abetting
# abetting
# abetting
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abdicates
# abducts
# abducting
# abducting
# abducting
# abducts
# abducts
# abducting
# absturing
# abducts
# abducting
# abducting
# abducts
# abducts
# abducts
# abducts
# abducts
# abounding
# abounding
# abounds
# abounds
# abounding
# abounds
# abounding
# abounds
# abounding
# abounds
# abounds
# abounding
# abounds
# abounding
# abounds
# abounds
# absorbs
# absorbs
# absorbs
# absorbs
# absorbs
# absorbs
# absorbs
# absorbs
# absorbed
# absorbs
# absorbs
# absorbs
# absorbs
# absorbs
# absorbs
# absorbs
# accept
# accepted
# accept
# accepted
# accept
# cancering
# accepting
# accepting
# accepted
# accept
# accept
# accept
# accept
# accepting
# accept
# accepting
# accompanies
# accompanying
# accompany
# accompanies
# accompany
# accompanies
# accompanies
# accompanying
# accompanies
# accompanying
# accompanies
# accompanies
# accompany
# accompanies
# accompanying
# accompanying
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accomplishes
# accounts
# accounts
# accounts
# accounts
# accounts
# accounts
# accounts
# accounts
# accounts
# accounted
# accounts
# accounts
# accounted
# accounts
# accounts
# accounted
# accuse
# accused
# accuse
# accuse
# accuse
# accuse
# accuse
# accuse
# accuses
# accuse
# accuse
# accuses
# accuse
# accuse
# accuse
# accuse
# aches
# aches
# aches
# aches
# aches
# aches
# aches
# aches
# ached
# aches
# ached
# aching
# aches
# ached
# aches
# aches
# achieves
# achieve
# achieve
# achieves
# achieve
# achieving
# achieve
# achieves
# achieves
# achieved
# achieves
# achieve
# achieve
# achieve
# achieve
# achieves
# conawleages
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acknowledge
# acquires
# acquires
# acquires
# acquires
# acquires
# acquires
# acquires
# acquires
# acquires
# acquire
# acquire
# acquires
# acquires
# acquires
# acquires
# acquires
# abstracting
# abstracting
# abstracts
# abstracts
# abstracting
# abstracts
# abstracting
# abstracts
# abstracts
# abstracts
# abstracts
# abstracting
# abstracts
# abstracts
# abstracts
# abstracts
# adding
# adding
# add
# adds
# adding
# adding
# add
# add
# add
# add
# added
# add
# adding
# adding
# add
# add
# addresses
# addresses
# addresses
# addresses
# addresses
# addresses
# addresses
# addresses
# addresses
# addressen
# addresses
# addressing
# addresses
# addresses
# addresses
# addresses
# adjoining
# adjoining
# adjoins
# adjoins
# adjoins
# adjoins
# adjoins
# adjoin
# adjoin
# adjoining
# adjoining
# adjoins
# adjoin
# adjoining
# adjoins
# adjoins
# adjourns
# adjourns
# adjourning
# adjourn
# adjourns
# adjourn
# adjourns
# adjourns
# adjourning
# adjourns
# adjourns
# adjourns
# adjourning
# adjourns
# adjourn
# adjourning
# adjusts
# adjusting
# adjusts
# adjusts
# adjusting
# adjusts
# adjusting
# adjusting
# adjust
# adjusts
# adjusting
# adjusting
# adjusting
# adjusting
# adjusting
# adjusts
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admire
# admits
# admitted
# admits
# admits
# admitted
# admitted
# admitted
# admitted
# admitted
# admitted
# admitted
# admitted
# admitted
# admitted
# admitted
# admitted
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# admonishes
# adopts
# adopts
# adopts
# adopts
# adopting
# adopts
# adopts
# adopts
# adopts
# adopts
# adopts
# adopts
# adopts
# adopts
# adopts
# adopts
# advance
# advance
# advances
# advance
# advance
# advances
# advances
# advances
# advances
# advance
# advances
# advances
# advance
# advances
# advance
# advances
# advertise
# advertise
# advertise
# advertise
# advertise
# advertise
# advertise
# advertises
# advertise
# advertise
# advertise
# advertise
# advertise
# advertise
# advertise
# advertises
# advises
# advises
# advises
# advises
# advise
# advises
# davise
# advises
# advising
# advises
# advise
# advise
# advises
# advises
# advises
# advises
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# advocates
# affects
# affects
# affects
# affects
# affected
# affects
# affects
# affects
# affect
# affects
# facate
# affects
# affect
# affects
# affected
# affects
# affirms
# affirms
# affirming
# affirms
# affirms
# affirms
# affirms
# affirms
# affirms
# affirms
# affirms
# affirms
# affirms
# affirms
# affirming
# affirming
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# affords
# agreeing
# agreeing
# agreeing
# agreeing
# agreeing
# agreeing
# agreeing
# agreeing
# agreeing
# agreeing
# agree
# agreeing
# agreeing
# agreeing
# agreeing
# agreeing
# aids
# aids
# aid
# aids
# aids
# aids
# aids
# aids
# aid
# aids
# aids
# aids
# aid
# aids
# aid
# aid
# acclaims
# acclaiming
# acclaiming
# acclaim
# acclaiming
# calatifing
# acclaiming
# acclaiming
# acclaims
# acclaiming
# acclaiming
# acclaiming
# acclaiming
# acclaiming
# acclaims
# acclaims
# allege
# allege
# allege
# allege
# allege
# allege
# allege
# alleges
# allege
# allege
# allege
# allege
# allege
# allege
# allege
# allege
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allocates
# allotting
# allots
# allots
# allots
# allotting
# allotting
# allotting
# allotting
# allotting
# allotting
# allotting
# allotting
# allotting
# allotting
# allotting
# allotting
# allow
# allowed
# allows
# allowing
# allowing
# allowed
# allowed
# allowing
# allowed
# allowed
# allowed
# allow
# allowing
# allowed
# allowed
# allowed
# alters
# alters
# alters
# ather
# alters
# alters
# alters
# alters
# alters
# alters
# alters
# alters
# alters
# alters
# alters
# alters
# matend
# amends
# amends
# amends
# amends
# amends
# amends
# amends
# amends
# amends
# amending
# amends
# amend
# amends
# amends
# amends
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amounts
# amuses
# amuse
# amuse
# amuse
# amuses
# amuse
# amuses
# amuses
# amuse
# amuses
# amuse
# amuses
# amuse
# amuses
# amuses
# amuses
# announces
# announces
# announces
# announces
# announces
# announce
# announces
# announces
# announces
# announces
# announces
# announces
# announces
# announces
# announces
# announces
# answers
# answers
# answer
# answers
# answers
# answers
# answers
# answers
# answers
# answers
# answers
# answers
# answers
# answering
# answers
# answering
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# anticipates
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# apologizes
# appealing
# appealing
# appealing
# appealing
# appealing
# appealing
# appealing
# appealing
# appealing
# appealing
# appealing
# appealing
# appeal
# appeals
# appealing
# appeals
# appearing
# appearing
# appearing
# appears
# appears
# appease
# appearing
# appearing
# appearing
# appearing
# appears
# appears
# appears
# appears
# appears
# appearing
# apply
# applying
# apply
# apply
# applied
# applied
# applied
# applied
# applied
# applies
# applied
# applied
# applied
# applies
# apply
# applies
# appoints
# appoints
# appoints
# appoints
# appoints
# appoints
# appoints
# appoints
# appoints
# appoints
# appoints
# paintain
# appoints
# appoints
# appoints
# appoints
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# appreciates
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approaches
# approve
# approves
# approve
# approve
# approve
# approve
# approve
# approve
# approve
# approve
# approve
# approve
# approve
# approve
# approves
# approves
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# approximates
# arching
# arching
# arching
# arches
# arches
# arching
# arches
# arching
# arches
# arries
# arches
# arches
# arches
# arching
# arches
# arches
# argues
# argue
# argues
# argue
# argues
# argue
# argue
# argue
# argues
# argues
# arguing
# argue
# argues
# arguing
# argue
# argue
# arosing
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arouses
# arraigns
# arraigns
# arraigns
# arraigns
# arraigns
# arraigns
# arraigns
# arraigning
# arraigning
# arraigns
# arraigns
# arraigns
# arraigning
# arraigning
# arraigned
# arraigning
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrange
# arrested
# arrests
# arrests
# arrests
# arrests
# arresting
# arrests
# arrested
# arrests
# arrests
# arrests
# arrested
# arrests
# arrests
# arrests
# arrests
# arrive
# arrive
# arrive
# arrive
# arrive
# arrive
# arrive
# arrive
# arrive
# arrive
# arrives
# arrives
# arrive
# arrive
# arrive
# arrives
# ascends
# ascends
# ascends
# ascends
# ascends
# ascends
# ascending
# ascends
# ascending
# ascends
# ascends
# ascends
# ascends
# ascends
# ascends
# ascends
# asking
# asking
# asking
# asking
# asking
# asking
# asking
# asks
# asks
# asking
# asking
# asking
# asking
# asking
# asking
# asking
# assaults
# assaulting
# assalt
# assaulted
# assaulted
# assault
# assault
# assaulted
# assault
# assault
# assault
# assault
# assault
# assault
# assault
# assault
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assembles
# assents
# assenting
# assenting
# assenting
# assents
# assenting
# assents
# assents
# assenting
# assenting
# assenting
# assenting
# assents
# assents
# assenting
# assenting
# asserts
# asserts
# asserts
# asserts
# asserts
# asserted
# asserts
# asserts
# asserts
# asserts
# asserting
# asserts
# asserts
# asserts
# asserts
# asserts
# assigning
# assign
# assign
# assigning
# assigning
# assigning
# assigning
# assigning
# assigning
# assigning
# assigning
# assigning
# assigning
# assigning
# assigning
# assigning
# assists
# assists
# assisting
# assists
# assisting
# assisting
# assists
# assisting
# assists
# assists
# assists
# assisting
# assists
# assists
# assisting
# assists
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# associates
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assume
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# assure
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attaches
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attacks
# attain
# attain
# attain
# attain
# attain
# attain
# attain
# attain
# attaining
# attain
# attaining
# attaining
# attain
# attaining
# attaining
# attaining
# attempts
# attempt
# attempting
# attempts
# attempts
# attempt
# attempts
# attempt
# attempts
# attempts
# attempts
# attempts
# attempts
# attempts
# attempts
# attempts
# attends
# attends
# attends
# attends
# tantens
# attends
# attends
# attends
# attends
# attends
# attends
# attends
# attends
# attends
# attends
# attends
# attests
# attests
# attests
# attesting
# attesting
# attests
# attests
# attests
# attests
# attesting
# attests
# attests
# attests
# attests
# attests
# attests
# attracts
# attracts
# attracts
# attracts
# attracts
# attracting
# attracts
# attracts
# attracting
# attracted
# attracting
# attracts
# attracts
# attracts
# attracts
# attracting
# attributes
# attribute
# attributes
# attribute
# attributes
# attribute
# attribute
# attribute
# attribute
# attribute
# attributes
# attributes
# attribute
# attributes
# attribute
# attributes
# augments
# augments
# amignates
# augments
# augments
# augments
# augments
# augments
# augments
# augments
# augments
# augmenting
# augments
# augmenting
# augmenting
# augmenting
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# authorizes
# avails
# avails
# availing
# availing
# avails
# avails
# avails
# avails
# availing
# availing
# ackiling
# availing
# availing
# availing
# avails
# avails
# average
# average
# average
# averages
# average
# averages
# averaged
# average
# average
# average
# averaged
# avergane
# average
# average
# averaged
# averages
# averts
# averts
# averts
# averts
# averts
# averts
# averts
# averts
# averts
# averts
# avert
# averts
# averts
# avert
# averts
# averts
# avoid
# avoid
# avoid
# avoid
# avoid
# avoiding
# avoids
# avoiding
# avoids
# avoiding
# avoids
# avoids
# avoiding
# avoiding
# avoiding
# avoid
# awaits
# awaits
# awaits
# awaits
# awaits
# awaits
# awaiting
# awaited
# awaits
# awaits
# awaits
# awaiting
# awaited
# awaits
# awaits
# awaited
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# awards
# babbles
# babble
# babble
# babbles
# babbles
# babbles
# babbles
# babbles
# babbles
# babble
# babbles
# babbles
# babble
# babbles
# babbles
# babbles
# backing
# backing
# backing
# back
# backs
# backs
# backing
# backs
# backs
# backs
# backing
# backing
# backed
# backing
# backing
# backs
# balking
# balking
# balking
# balking
# balking
# balking
# balks
# balking
# balking
# balks
# balking
# balking
# balking
# balking
# balking
# balks
# bangs
# bang
# bang
# bang
# banging
# banging
# banging
# bangs
# banging
# banging
# banging
# banging
# banging
# banging
# banging
# banging
# barring
# barring
# bar
# barring
# barring
# barring
# bars
# barring
# barring
# barring
# barring
# barring
# barring
# barring
# barring
# barring
# abases
# abases
# abase
# abase
# abase
# abase
# abases
# abase
# abasing
# abassed
# abase
# abasing
# abases
# abases
# abassed
# abases
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# batters
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bawls
# bays
# baying
# baying
# baying
# bays
# baying
# baying
# baying
# baying
# baying
# baying
# baying
# baying
# bays
# bays
# bays
# beckons
# beckons
# beckon
# beckon
# beckons
# beckons
# beckon
# beckon
# beckons
# beckoning
# beckons
# beckons
# beckons
# beckon
# beckons
# beckons
# begging
# geaze
# begging
# begging
# begging
# begging
# begging
# begging
# begging
# begging
# begging
# begging
# begging
# begging
# begging
# begs
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# behave
# belches
# belched
# belches
# belches
# belches
# belched
# belches
# belches
# belches
# belches
# belches
# belches
# belches
# belches
# belches
# belches
# belie
# belies
# belies
# belied
# belies
# belies
# belies
# belies
# belie
# belie
# belie
# belie
# belied
# belied
# belied
# belied
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# believe
# bellowing
# bellowing
# bellow
# bellows
# bellowing
# bellowing
# bellowing
# bellowing
# bellowing
# bellow
# bellowing
# bellows
# bellows
# bellows
# bellowing
# bellowing
# belong
# belongs
# belonging
# belonging
# belongs
# belonging
# belonging
# belonging
# belonging
# belonging
# belonging
# belonging
# belonging
# belonging
# belonging
# belonging
# belt
# belt
# belting
# belt
# belt
# belt
# belt
# belt
# belt
# belt
# belt
# belts
# belt
# belt
# belting
# belt
# bestowing
# bestow
# bestow
# bestow
# bestowing
# bestow
# bestow
# bestowed
# bestow
# bestow
# bestowing
# bestow
# bestowing
# bestow
# bestow
# bestow
# betrays
# betray
# betraying
# betraying
# betraying
# betray
# betrays
# betrays
# betray
# betraying
# betrays
# betraying
# betraying
# betraying
# betraying
# betrays
# blames
# blame
# blame
# blame
# blames
# blame
# blame
# blame
# blames
# blame
# blames
# blame
# blame
# blames
# blame
# blame
# blasts
# blasts
# blasting
# blasts
# blasts
# blasts
# blasting
# blasts
# blasts
# blasting
# blasts
# blasts
# blasts
# blasting
# blasting
# blasts
# blazing
# blazes
# blazes
# blazing
# blazes
# blazes
# blazes
# blazes
# blazing
# blazes
# blazing
# blazes
# blazes
# blazes
# blazes
# blazes
# bleeds
# bleeds
# bleed
# bleeds
# blenging
# bleeds
# bleeds
# bleeds
# bleeding
# blenged
# bleeds
# blends
# bleed
# bleed
# bleed
# bleeding
# blends
# blends
# blends
# blends
# blends
# blends
# blend
# blends
# blends
# blends
# beln
# blent
# blent
# blent
# blent
# blent
# blinking
# blinking
# blinks
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blinking
# blocking
# blocking
# blocks
# block
# blocks
# blocks
# blocks
# blocks
# blocks
# block
# blocked
# blocked
# blocked
# blocks
# blocks
# blocks
# blomping
# bloom
# bloom
# bloomed
# blooming
# bloom
# bloom
# bloom
# bloom
# bloom
# bloom
# bloom
# bloom
# bloom
# bloomed
# bloomed
# blurts
# blurts
# blurt
# blurt
# blurt
# blurt
# blurts
# blurt
# blurts
# blurts
# blurts
# blurt
# blurts
# blurts
# blurts
# blurt
# blushed
# blushed
# blushed
# blushed
# blushed
# blushes
# blushed
# blushed
# blushes
# blushed
# blushed
# blushes
# blushed
# blushed
# blushes
# blushed
# boasted
# boasting
# boasting
# boast
# boast
# boasted
# boasting
# boast
# boast
# boasted
# boast
# boast
# boasting
# boast
# boasted
# boasted
# bolted
# bolted
# bolts
# bolts
# bolt
# bolted
# bolted
# bolts
# bolted
# bolted
# bolts
# bolts
# bolts
# bolted
# bolts
# bolts
# boost
# boost
# boosting
# boosting
# boost
# boosting
# boosting
# boosting
# boosted
# boost
# boost
# boosting
# boosting
# boosting
# boosting
# boosting
# borrows
# borrows
# borrowing
# borrowing
# borrowing
# borrowing
# borrow
# borrows
# borrowing
# borrow
# borrowing
# borrowing
# borrows
# borrows
# borrows
# borrowing
# bothers
# bothers
# bothers
# bothers
# bothers
# bothers
# bothers
# bothers
# bothers
# bothers
# bothers
# bothers
# bothers
# bothering
# bothers
# bothers
# bounces
# bounces
# bounces
# bounce
# bounces
# bounces
# bounces
# bounces
# bounce
# bounces
# bounces
# bounces
# bounces
# bounces
# bounced
# bounces
# bow
# bow
# bow
# bowing
# bow
# bow
# bow
# bows
# bow
# bowing
# bowing
# bow
# bowing
# bows
# bowed
# bows
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragging
# bragged
# bragging
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breakfasting
# breathes
# breathes
# breathed
# breathes
# breathe
# breathes
# breathes
# breathes
# breathes
# breathes
# breathes
# breathes
# breathes
# breathed
# breathes
# breathes
# bribe
# bribe
# bribe
# bribe
# bribe
# bribe
# bribe
# bribe
# bribing
# bribe
# bribe
# bribe
# bribe
# bribe
# bribe
# bribe
# brightens
# brightens
# brightens
# brightens
# brightens
# brightens
# brightens
# brighten
# brightens
# brightens
# brightens
# brightens
# brightens
# brightens
# brightens
# brightens
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# bristles
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# broadens
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# brushes
# bulge
# bulge
# bulge
# bulge
# bulged
# bulge
# bulge
# bulge
# bulged
# bulged
# bulged
# bulged
# bulged
# bulged
# bulged
# bulge
# bumps
# bumps
# bumping
# bumpled
# bumps
# bumps
# bumping
# bumping
# bumping
# bumping
# bumping
# bumping
# bumping
# bumping
# bumping
# bumped
# buries
# bury
# buries
# buries
# buries
# bury
# buried
# bury
# buries
# buried
# buries
# buries
# buried
# buries
# buries
# buries
# burns
# burns
# burns
# burn
# burn
# burn
# burn
# burn
# burn
# burning
# burns
# burns
# burns
# burns
# burns
# burn
# buzzed
# buzzed
# buzzing
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# buzzed
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# cackle
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calculates
# calling
# calls
# call
# calls
# calls
# calling
# calling
# calls
# calling
# calling
# calls
# call
# calling
# call
# calling
# call
# campaigned
# campaigns
# campaigns
# campaigns
# campaigns
# acchinates
# campaigning
# acplaining
# campaigns
# campaigns
# campaigns
# campaigning
# campaigning
# campaigning
# campaigning
# campaigns
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# capitulates
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# captures
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# cares
# caresses
# caresses
# caresses
# caresses
# caresses
# caresses
# caresses
# caressed
# caresses
# caresses
# caresses
# caressing
# caresses
# caresses
# caresses
# caresses
# carrying
# carries
# carry
# carries
# carries
# carries
# carries
# carries
# carrying
# carries
# carries
# carries
# carries
# carries
# carries
# carries
# broadcasts
# broadcasts
# broadcasts
# broadcasts
# broadcasting
# broadcasts
# broadcasts
# broadcasting
# broadcasts
# broadcasts
# broadcasts
# broadcasting
# broadcasts
# broadcasts
# broadcasts
# broadcasts
# cause
# cause
# causes
# caused
# causes
# causes
# causes
# cause
# causes
# causes
# causes
# causes
# causes
# causes
# causes
# cause
# cautioning
# cautioning
# caution
# cautions
# cautions
# catimize
# caution
# cautions
# cautioning
# cautions
# cautioning
# cautions
# cautions
# cautioning
# cautioning
# caution
# cease
# ceases
# ceases
# cease
# ceases
# ceases
# ceases
# cease
# ceases
# ceasing
# ceases
# ceases
# cease
# cease
# ceases
# cease
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# celebrates
# challenged
# challenged
# challenged
# challenge
# challenge
# challenge
# challenge
# challenge
# challenged
# challenged
# challenged
# challenged
# challenged
# challenged
# challenge
# challenged
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# chances
# changes
# changed
# change
# change
# changed
# changes
# changes
# changed
# changes
# changed
# change
# changes
# changed
# changes
# changed
# changed
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# chants
# characterize
# characterize
# characterize
# characterize
# characterize
# characterize
# characterize
# characterize
# charatifering
# characterize
# characterize
# characterize
# characterize
# characterize
# characterize
# characterize
# charge
# charges
# charges
# charges
# charges
# charges
# charge
# charges
# charges
# charges
# charges
# charges
# charge
# charges
# charge
# charges
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# chatting
# checks
# checks
# checking
# checks
# checks
# checks
# checking
# checking
# checks
# checks
# checks
# checking
# checking
# checks
# checks
# checks
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# cherishes
# chew
# chew
# chews
# chewing
# chews
# chews
# chew
# chew
# chewing
# chew
# chew
# chew
# chewing
# chew
# chew
# chew
# chills
# chills
# chills
# chills
# chills
# chilling
# chills
# chilling
# chills
# chilling
# chilled
# chilling
# chilling
# chilling
# chilling
# chilling
# chortle
# chortles
# chortles
# chortles
# chortle
# chortle
# chortles
# chortle
# chortle
# chortles
# chortle
# chortle
# chortles
# chortles
# chortles
# chortles
# chuckles
# chuckle
# chuckles
# chuckles
# chuckle
# chuckle
# chuckles
# chuckles
# chuckle
# chuckles
# chuckle
# chuckles
# chuckles
# chulced
# chuckles
# chuckles
# circles
# circles
# circles
# circles
# circles
# circles
# circles
# circled
# circles
# circles
# circles
# circles
# circles
# circles
# circles
# circles
# circulates
# circulates
# circulates
# circulates
# circulates
# circalate
# circulates
# circulates
# circulates
# circulates
# circulates
# circulates
# circulates
# circulates
# circulates
# circulates
# cites
# cite
# cites
# cites
# cites
# cites
# cite
# cite
# cite
# cites
# cites
# cites
# cites
# cites
# cites
# cites
# clambering
# clambering
# clambers
# clambering
# clambering
# clambering
# clambering
# clamber
# clambers
# clambers
# clambering
# clambering
# clambering
# clambering
# clambers
# clambering
# clamping
# clamping
# clamps
# clamping
# clamps
# clamps
# clamping
# clamping
# clamping
# clamping
# clamping
# clamping
# clamping
# clamping
# clamping
# clamping
# clapping
# clapping
# clapping
# clapping
# clapping
# clapping
# clapping
# clapping
# clapping
# clapping
# clapped
# clapping
# clapping
# clapping
# clapping
# clapping
# clasps
# clasps
# clasps
# clasping
# clasping
# clasps
# clasping
# clasping
# clasping
# clasping
# clasping
# clasping
# clasping
# clasps
# clasping
# clasping
# clatters
# clattered
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clatters
# clicks
# clicks
# clicks
# clicks
# clicks
# clicking
# clicks
# clicking
# clicking
# clicking
# clicks
# clicks
# clicks
# clicks
# clicking
# clicks
# climbed
# climbing
# climbing
# climbing
# climbing
# climbing
# climbing
# climbed
# climb
# climbing
# climbing
# climbing
# climbing
# climbing
# climbing
# climbed
# bicycled
# bicycled
# bicycles
# bicycled
# bicycled
# bicycled
# bicycled
# bicycles
# bicycles
# bicycles
# bicycles
# bicycled
# bicycled
# bicycles
# bicycles
# bicycled
# clip
# clipping
# clipping
# clipping
# clips
# clipping
# clipping
# clip
# clipping
# clipping
# clipping
# clipping
# clipping
# clipping
# clipping
# clipping
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# clutches
# coasting
# coasting
# coasting
# coasting
# coasting
# coasting
# coasted
# coasting
# coasting
# coasting
# coasting
# coasting
# coasting
# coasts
# coasting
# coasting
# coincides
# coincides
# coincides
# coicinies
# coincides
# coincides
# coincides
# coincides
# coincides
# coincides
# coincides
# coincides
# coincides
# coincides
# coincides
# coincides
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collaborates
# collapse
# collapses
# collapse
# collapsed
# collapses
# collapse
# collapses
# collapsed
# collapse
# collapse
# collapsed
# collapse
# collapse
# collapse
# collapsed
# collapsed
# collected
# collected
# collects
# collected
# collected
# collects
# collected
# collects
# collects
# collects
# collected
# collects
# collects
# collected
# collected
# collected
# combines
# combines
# combines
# combines
# combined
# combines
# combines
# combines
# combines
# combines
# combines
# combines
# combined
# combines
# combined
# combines
# commands
# commands
# commanding
# commands
# commands
# commands
# commands
# commands
# commands
# commands
# commands
# commands
# commanding
# commands
# commands
# commands
# commences
# commences
# commences
# commences
# commences
# commences
# commences
# commences
# commenced
# commences
# commenced
# commences
# commences
# commences
# commences
# commences
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# comments
# committing
# committing
# committing
# committing
# committing
# committing
# committing
# committing
# committing
# committing
# commits
# committing
# committing
# committing
# committing
# committing
# compares
# compares
# compares
# compare
# compares
# compares
# compares
# compared
# comparing
# compares
# comparing
# comparing
# comparing
# compares
# compares
# compares
# competed
# competes
# compete
# competes
# competes
# competed
# compete
# competes
# compete
# competes
# competes
# compete
# competes
# competes
# competes
# competes
# compiles
# compiles
# compiles
# compiles
# compiles
# compiles
# compiles
# compiles
# compiling
# compiles
# compiles
# compiles
# compiles
# compiles
# compiles
# compiles
# complains
# complaining
# complaining
# complaining
# complaining
# complaining
# complain
# complaining
# complaining
# complained
# complained
# complaining
# complains
# complaining
# complains
# complains
# completed
# completed
# completes
# completes
# completes
# complete
# completes
# completes
# completes
# completes
# complete
# completes
# completes
# completed
# completes
# completed
# complying
# complying
# complying
# complying
# complies
# complies
# complies
# complying
# complies
# complies
# complies
# complied
# comply
# complies
# complies
# complies
# compose
# composed
# composen
# composed
# compose
# composes
# compose
# composes
# composen
# composen
# composen
# composes
# compose
# composes
# compose
# compose
# comprise
# comprise
# comprises
# comprises
# comprise
# comprise
# comprise
# comprises
# comprise
# compisting
# comprise
# comprise
# comprise
# comprise
# comprises
# comprises
# concedes
# concedes
# concedes
# concedes
# concedes
# concede
# concedes
# concede
# concedes
# concedes
# concends
# concedes
# concedes
# concedes
# concedes
# concedes
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# conceives
# concerns
# concerns
# concerns
# concerns
# concerns
# concerns
# concerns
# concerns
# concerns
# concerns
# concerns
# concerns
# concern
# concern
# concern
# concerns
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concludes
# concurring
# concurring
# concur
# concur
# concurs
# concurs
# concurs
# concurring
# concurring
# concurring
# concurring
# concurring
# concurring
# concur
# concurring
# concurring
# condemns
# condemns
# connew
# condemns
# condemning
# condemns
# condemns
# condemns
# condemns
# condemns
# condemns
# condemning
# condemns
# condemning
# condemning
# condemning
# conducted
# conducted
# conducts
# conducting
# conducting
# conducted
# conducting
# conducting
# conducting
# conducted
# conducting
# conducting
# conducted
# conducting
# conducting
# conducting
# confesses
# confesses
# confessed
# confessed
# confessed
# confesses
# confessed
# confesses
# confesses
# confesses
# confesses
# confessed
# confessed
# confessed
# confessed
# confessed
# confides
# confides
# confides
# confides
# confides
# confides
# confides
# confide
# confides
# confides
# confides
# confides
# confides
# confides
# confides
# confides
# confirm
# confirm
# confirm
# confirm
# confirms
# confirms
# confirms
# confirms
# confirm
# confirm
# confirms
# confirms
# confirms
# confirms
# confirmed
# confirmed
# confronting
# confronted
# confront
# confronted
# confronts
# confronted
# confront
# confronts
# confronts
# confront
# confronts
# confront
# confronts
# confronted
# confronts
# confronting
# confuse
# confused
# confuses
# confused
# confused
# confuse
# confuses
# confuses
# confuse
# confused
# confuses
# confused
# confuses
# confuse
# confuses
# confuse
# congeals
# congeal
# congeals
# congeal
# congeal
# congeal
# congeal
# congealing
# congeal
# congeal
# congeal
# congeal
# congealing
# congeal
# congeal
# congeal
# connects
# connects
# connected
# connects
# connects
# connects
# connects
# connecting
# connects
# connects
# connects
# connects
# connects
# connects
# connects
# connects
# consent
# consents
# consents
# consents
# consents
# consent
# consents
# consenting
# consents
# consents
# consents
# consents
# consenting
# consents
# consents
# consents
# considers
# considers
# considers
# considers
# considers
# considering
# considers
# considers
# considers
# considering
# considers
# considering
# considering
# considers
# considering
# considers
# consisted
# consisted
# consisted
# consisted
# consisting
# consists
# consisting
# consists
# consisting
# consisting
# consisting
# consisting
# consisting
# consisting
# consisting
# consisting
# conspires
# conspires
# conspires
# conspire
# conspire
# conspires
# conspires
# conspires
# conspires
# conspire
# conspires
# conspires
# conspires
# conspires
# conspires
# conspires
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constitutes
# constructed
# constructed
# constructed
# constructed
# constructs
# constructed
# constructed
# constructed
# constructed
# constructed
# constructed
# constructed
# constructs
# constructed
# constructed
# constructs
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# consults
# contacts
# contacts
# contacts
# contacts
# contacts
# contacts
# contacts
# contacts
# contacts
# contacts
# contacts
# contacts
# contacts
# contacting
# contacts
# contacts
# containing
# containing
# containing
# contain
# containing
# containing
# contain
# containing
# contain
# containing
# containing
# contains
# containing
# contain
# containing
# contain
# contends
# contends
# contends
# contends
# contends
# contends
# contends
# contends
# contends
# contending
# contends
# contends
# contends
# contends
# contends
# contends
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# continues
# contracted
# contracted
# contracted
# contracted
# contracts
# contracted
# contracted
# contracted
# contracted
# contracted
# contracted
# contracted
# contracted
# contracted
# contracted
# contracts
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# contributes
# controls
# controlling
# controlling
# controls
# controls
# controlling
# controls
# controls
# controlling
# controlling
# controlling
# controlling
# controlling
# controlling
# controlling
# controlling
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# convenes
# converts
# converts
# converts
# convert
# convert
# converts
# converts
# convert
# convert
# converts
# converts
# converts
# converts
# converts
# converts
# converts
# conveys
# conveys
# conveying
# conveys
# convey
# conveying
# conveys
# conveying
# conveys
# conveying
# conveys
# conveying
# conveying
# conveying
# conveys
# conveys
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# convinces
# cook
# cooking
# cook
# cooking
# cooking
# cooking
# cooking
# cooking
# cooking
# cooking
# cooking
# cooking
# cooking
# cooking
# cook
# cook
# corrects
# corrects
# corrects
# corrects
# corrects
# corrects
# corrects
# corrects
# corrects
# corrects
# corrects
# corrects
# corrects
# creccoses
# corrects
# corrects
# corresponds
# roccorsent
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# corresponds
# accosting
# accosts
# accosting
# accosts
# accosts
# accosts
# accosting
# accosts
# accosts
# accosts
# accosts
# accosts
# castaces
# accosts
# accosts
# accosts
# coughed
# coughs
# coughed
# coughs
# coughed
# coughs
# coughing
# coughing
# coughs
# coughing
# coughing
# coughs
# coughing
# coughed
# coughing
# coughing
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counselling
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# counters
# couple
# couple
# couple
# couple
# couple
# couple
# couple
# couple
# coupling
# coupling
# couple
# couple
# couple
# couple
# couple
# couple
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# covers
# cracks
# cracks
# cracks
# cracks
# cracks
# cracks
# cracks
# cracks
# cracking
# cracks
# cracks
# cracks
# cracks
# cracks
# cracks
# cracks
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crashes
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# crawls
# creaking
# creaking
# creaks
# creaking
# creaking
# creaking
# creaking
# creaking
# creaks
# creaking
# creaks
# creaking
# creaks
# creaking
# creaking
# creaking
# created
# create
# create
# create
# create
# create
# create
# create
# create
# create
# create
# create
# create
# created
# create
# create
# accredited
# accrediting
# accredited
# accredited
# accrediting
# accrediting
# accredits
# accredited
# accredited
# accredited
# accrediting
# accrediting
# accrediting
# accredited
# accredited
# accrediting
# cringed
# cringing
# cringed
# cringe
# cringes
# cringes
# cringe
# cringes
# cringed
# cringing
# cringe
# cringing
# cringes
# cringes
# cringing
# preaves
# criticized
# criticize
# criticized
# criticizes
# criticizes
# criticize
# criticizes
# criticizes
# criticize
# criticize
# criticize
# criticize
# criticizes
# criticize
# criticize
# criticized
# croons
# crooning
# croons
# croons
# croons
# croon
# croon
# croons
# croons
# croons
# crooning
# croons
# croons
# croons
# croons
# croons
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crouches
# crowd
# crowding
# crowd
# crowd
# crowd
# crowd
# crowd
# crowd
# crowd
# crowding
# crowding
# crowding
# crowding
# crowding
# crowd
# crowd
# crows
# crowing
# crows
# crow
# crow
# crows
# crows
# crow
# crowing
# crowing
# crows
# crowing
# crew
# cringing
# crew
# criwed
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# crushes
# cried
# cries
# cries
# cray
# cries
# crien
# cries
# cries
# cried
# cried
# cried
# chires
# cried
# cries
# cried
# cries
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# culminates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# cultivates
# curls
# curls
# curls
# curls
# curls
# curls
# curls
# curls
# curls
# curls
# curls
# curls
# curls
# cult
# curls
# curls
# curses
# curses
# curse
# curse
# curses
# curse
# curse
# curse
# curst
# curst
# curst
# curse
# cursed
# curse
# curse
# curse
# damage
# damages
# damages
# damage
# damage
# damage
# damaged
# admuged
# damaged
# damaged
# admaging
# damaged
# damage
# damages
# damages
# damage
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# dangles
# daring
# dag
# dares
# daring
# dare
# daring
# dares
# dare
# daring
# daring
# daring
# daring
# daring
# dares
# daring
# dares
# darkens
# darkens
# darkening
# darkens
# darkens
# darkening
# darkens
# darkens
# darkening
# darkening
# darkening
# darkening
# darkening
# darkens
# darkens
# darkening
# darts
# darts
# darts
# darts
# darts
# darts
# darts
# darts
# darts
# darts
# darts
# darts
# dart
# darts
# darts
# darts
# dashes
# dashes
# dashes
# dashed
# dashes
# dashes
# dashes
# dashes
# dashes
# dashes
# dashed
# dashing
# dashes
# dashes
# dashes
# dashed
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# decides
# declaiming
# declaiming
# declaim
# declaiming
# declaiming
# declaim
# declaiming
# declaiming
# declaim
# declaim
# declaiming
# declaiming
# declaiming
# declaiming
# declaiming
# declaim
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# declares
# decline
# decline
# decline
# declines
# declines
# declines
# declines
# declines
# declines
# decline
# declines
# declines
# decline
# declines
# declines
# declines
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decreases
# decried
# decries
# decry
# decried
# decried
# decried
# decried
# decried
# decried
# decried
# decried
# decries
# decried
# decried
# decried
# decried
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# dedicates
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deduce
# deeming
# deems
# deeming
# deems
# deems
# deeming
# deeming
# deems
# deems
# dement
# deems
# deeming
# deems
# deems
# deeming
# deems
# defeating
# defeating
# defeating
# defeating
# defeats
# defeating
# defeating
# defeating
# defeating
# defeating
# defeats
# defeating
# defeats
# defeating
# defeating
# defeating
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defends
# defy
# defied
# defied
# defied
# defying
# defies
# defied
# defied
# defied
# defied
# defied
# defies
# defied
# defied
# defied
# defied
# delay
# delay
# delay
# delaying
# delay
# delay
# delay
# delay
# delay
# delay
# delay
# delay
# delay
# delay
# delay
# delay
# delieve
# delivered
# delivering
# delivering
# delivering
# delivering
# delivering
# delivering
# delivered
# delivering
# delivers
# delivering
# delivers
# delivering
# delivering
# delivering
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demands
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# nemostrates
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# demonstrates
# denies
# denying
# denies
# denies
# denies
# denies
# denies
# denies
# denies
# denying
# denies
# denies
# denies
# denies
# denied
# deny
# denotes
# denotes
# denites
# denotes
# denotes
# denotes
# denotes
# denotes
# denotes
# denotes
# denotes
# denotes
# denotes
# denotes
# denotes
# denotes
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# denounces
# departs
# departs
# depart
# departs
# departing
# departing
# departs
# departs
# departing
# departs
# departs
# departs
# depart
# departs
# departs
# departs
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depends
# depicts
# depicts
# depicts
# depicts
# depicts
# depicting
# depicts
# depicting
# depicts
# depicting
# depicting
# depicts
# depicts
# depicting
# depicting
# depicting
# deplores
# deplores
# deplore
# deplores
# deplores
# deplores
# deplores
# deplore
# deplores
# deplores
# deplores
# deplores
# deplores
# deplore
# deplores
# deplores
# condescending
# condescending
# condescending
# condescending
# condescends
# condescending
# condescending
# condescending
# condescends
# condescends
# condescends
# condescending
# condescends
# condescends
# condescending
# condescends
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# describes
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserves
# deserve
# designing
# designing
# designs
# designing
# designs
# designing
# designing
# designs
# design
# design
# design
# designs
# designs
# designing
# designs
# designing
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# designates
# desire
# desire
# desire
# desire
# desire
# desiren
# desire
# desire
# desire
# desire
# desire
# desire
# desire
# desire
# desire
# desire
# despises
# despises
# despises
# despises
# despises
# despises
# despises
# despises
# despises
# despise
# despises
# despises
# despise
# despises
# despises
# despises
# destroy
# destroy
# destroy
# destroys
# destroys
# destroys
# destroy
# destroy
# destroys
# destroys
# destroy
# destroy
# destroys
# destribes
# destroys
# destroys
# determine
# determine
# determine
# determine
# determines
# determine
# determines
# determine
# determine
# determines
# determines
# determine
# determines
# determines
# determines
# determines
# detesting
# detests
# detests
# detests
# detests
# detesting
# detesting
# detesting
# detest
# detests
# detests
# detests
# detests
# detests
# detests
# detests
# developing
# developing
# developing
# developing
# developing
# develops
# develops
# developing
# developing
# developing
# develops
# developing
# developing
# developing
# developing
# developing
# devised
# devised
# devising
# devised
# devised
# devise
# devised
# devised
# devised
# devised
# devise
# devise
# devised
# devised
# devise
# devised
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# devotes
# differs
# differs
# differs
# differs
# differs
# differs
# differs
# differs
# differs
# differs
# differing
# differs
# differs
# differing
# differs
# differs
# dine
# dines
# dines
# dines
# dines
# dine
# dines
# dines
# dines
# dine
# dines
# dine
# dines
# dines
# dines
# dine
# dipping
# dipping
# dipping
# dip
# dipping
# dipping
# dipping
# dips
# dipping
# dipping
# dipping
# dipping
# dips
# dipping
# dipped
# dipping
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# directs
# disagreeing
# disagreeing
# disagreeing
# disagreeing
# disagreeing
# disagreeing
# disagreeing
# disagreeing
# disagrees
# disagrees
# disagree
# disagreeing
# disagreeing
# disagreeing
# disagreeing
# disagreeing
# disappears
# disappears
# disappears
# disappears
# disappearing
# disappears
# disappears
# disappears
# disappears
# disappears
# disappears
# disappears
# disappears
# disappears
# disappears
# disappears
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapproves
# disapprove
# disapproves
# discipline
# disciplines
# discipline
# disciplines
# discipline
# disciplines
# disciplines
# discipline
# discipline
# discipline
# disciplines
# discipline
# discipline
# discipline
# dispilited
# discipline
# disclose
# discloses
# disclose
# disclose
# disclose
# disclose
# discloses
# disclose
# disclose
# disclose
# disclose
# disclose
# disclose
# disclose
# disclose
# discloses
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discontinues
# discounts
# discounts
# discounts
# discounts
# discounts
# discounting
# discounting
# discounting
# discounting
# discounting
# discounting
# discounted
# discounts
# discounting
# discuntin
# discounting
# discovering
# discovering
# discovering
# discovering
# discovered
# discovers
# discovers
# discovers
# discovers
# discovered
# discovers
# discovers
# discovers
# discovering
# discovers
# discovers
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# discusses
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disfigures
# disguise
# disguises
# disguise
# disguise
# disgisuing
# disguise
# disguises
# disguises
# disguises
# disguise
# disguises
# disguise
# disguises
# disguises
# disguise
# disguises
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dislike
# dismembers
# dismembering
# dismembered
# dismembers
# dismembers
# dismembers
# dismembers
# dismembered
# dismembered
# dismembered
# dismembered
# dismembers
# dismembers
# dismembers
# dismembers
# dismembered
# dismissed
# dismissed
# dismissed
# dismissed
# dismissed
# dismisses
# dismisses
# dismissed
# dismissed
# dismissed
# dismissed
# dismissed
# dismissed
# dismissed
# dismissed
# dismissed
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dismounts
# dispatches
# dispatches
# dispatches
# dispatches
# dispatches
# dispatches
# dispatches
# dispattens
# dispatches
# dispatches
# dispatches
# dispatches
# dispatched
# dispatches
# dispatches
# dispatches
# displays
# displaying
# displays
# displays
# displays
# display
# display
# displaying
# display
# display
# display
# displays
# display
# display
# display
# displays
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disposes
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregards
# disregarding
# disregards
# disrupting
# disrupts
# disrupting
# disrupting
# disrupting
# disrupting
# disrupting
# disrupting
# disrupts
# disrupts
# disrupts
# disrupting
# disrupts
# disrupting
# disrupts
# disrupting
# distracts
# distracts
# distracts
# distracts
# distracts
# distracts
# distracts
# distracts
# distracts
# distracts
# distracted
# distracts
# distracts
# distracts
# distracts
# distracts
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# distributes
# disturbing
# disturbing
# disturbing
# disturbing
# disturbing
# disturbing
# disturbing
# disturbs
# disturbing
# disturbs
# disturbs
# disturbs
# disturbing
# disturbing
# disturbing
# disturbing
# diving
# dive
# dive
# dive
# dive
# dive
# dive
# dive
# dive
# diving
# dive
# dive
# dive
# dive
# dive
# dive
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divides
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# divorces
# dodges
# dodge
# dodge
# dodge
# dodges
# dodge
# dodges
# dodge
# dodge
# dodges
# dodge
# dodges
# dodge
# dodge
# dodge
# dodges
# dominates
# dimonates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dominates
# dooming
# dooming
# dooming
# dooming
# doomed
# dooming
# dooming
# dooming
# dooming
# dooming
# dooming
# dooms
# dooming
# dooming
# dooming
# dooming
# doubled
# doubles
# doubles
# doubles
# doubles
# doubled
# doubles
# doubles
# doubles
# doubles
# doubles
# doubles
# doubled
# doubled
# doubles
# doubles
# doubting
# doubted
# doubting
# doubts
# doubts
# doubts
# doubts
# doubts
# doubts
# doubts
# doubts
# doubts
# doubting
# doubts
# doubts
# doubts
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# bulldozes
# drafts
# drafts
# drafts
# drafts
# draft
# drafts
# drafts
# draft
# drafts
# drafts
# drafts
# drafts
# drafts
# drafts
# drafts
# drafts
# dragging
# dragging
# dragging
# dragging
# dragging
# dragging
# drags
# dragging
# dragging
# dragging
# dragging
# dragging
# dragging
# dragging
# dragging
# dragging
# drain
# drains
# drain
# drains
# drains
# draining
# drain
# draining
# diraning
# drain
# drains
# drain
# draining
# draining
# drains
# draining
# drape
# drape
# drapes
# drape
# drape
# drape
# drapes
# drape
# drape
# drape
# drape
# drape
# drapes
# drape
# drape
# drapes
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# drawls
# daydreaming
# daydreaming
# daydreaming
# daydreaming
# daydreaming
# daydreams
# daydreaming
# daydreaming
# daydreams
# daydreaming
# daydreaming
# daydreaming
# daydreaming
# daydreaming
# daydreaming
# daydreams
# drifts
# drifts
# drifting
# drifted
# drifts
# drifts
# drifts
# drifts
# ...
# countersink
# countersank
# oversleeping
# oversleeping
# oversleeping
# oversleeps
# oversleeping
# overslept
# oversleeping
# overslept
# oversleeping
# overslept
# overslept
# overslept
# oversleeps
# oversleeps
# overslept
# overslept
# backslides
# backslides
# backslides
# backslides
# backslides
# backslid
# backslides
# backslides
# backslides
# backslides
# backslides
# backslides
# backslides
# backslides
# backslides
# backslides
# misspent
# misspends
# misspents
# misspends
# misspent
# misspends
# misspends
# misspends
# misspend
# misspends
# misspends
# mispends
# misspents
# misspent
# misspents
# misspent
# spinning
# spin
# spinning
# spinning
# spinning
# spinning
# spin
# spinning
# spinning
# spinning
# spinning
# spinning
# spinning
# spinning
# spinning
# spinning
# splitting
# splits
# splitting
# splits
# split
# splits
# splits
# split
# splitting
# splits
# splits
# splitting
# splits
# splits
# splits
# splitting
# springs
# spring
# spring
# spring
# springing
# springing
# springing
# springs
# springing
# springing
# springing
# sprang
# springs
# spring
# spring
# springing
# steals
# steals
# steals
# steals
# steals
# steals
# steals
# steals
# steals
# steals
# steals
# steals
# stelling
# steals
# steals
# steals
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# strive
# sweeps
# sweeping
# sweeps
# sweeps
# sweeping
# sweeping
# sweeps
# sweeps
# sweeping
# sweeping
# sweeps
# swept
# sweeps
# sweeping
# swept
# sweeping
# swim
# swim
# swim
# swim
# swim
# swim
# swims
# swim
# swim
# swim
# swimming
# swimming
# swam
# swam
# swam
# swam
# swings
# swings
# swings
# swings
# swinging
# swinging
# swings
# swings
# swinging
# swinning
# swinging
# swinging
# swings
# swings
# swings
# swings
# betake
# betake
# betake
# betake
# betake
# betake
# betake
# betake
# betake
# betake
# betake
# betaking
# betake
# betaking
# betake
# betake
# teaches
# tarce
# teaches
# teaches
# teaching
# teaches
# teaches
# teaches
# teaching
# teaches
# teaching
# teaches
# teach
# tagches
# taught
# taught
# tears
# tears
# tears
# tears
# tears
# tears
# tears
# tears
# tearing
# tears
# tears
# tears
# tears
# tears
# trode
# teal
# telapping
# radio
# heradining
# reainding
# telephone
# telephone
# treakoling
# telephone
# reaid
# radio
# teliphed
# reaid
# telephone
# telephone
# telephone
# telephone
# foretell
# foretell
# foretell
# foretell
# foretell
# foretell
# foretell
# foretell
# foretells
# foretell
# foretell
# foretell
# foretell
# foretell
# foretell
# foretell
# bethinking
# bethinking
# bethinking
# bethinking
# bethinking
# bethinking
# bethinking
# bethinking
# bethinking
# bethinking
# bethinking
# bethinking
# bethink
# sheatizling
# bethink
# bethink
# overthrow
# overthrow
# overthrow
# overthrow
# overthrows
# overthrowing
# overthrows
# overthrows
# overthrowing
# overthrowing
# overthrows
# overthrows
# overthrowing
# overthrow
# overthrow
# overthrow
# thrust
# thrust
# thrust
# thrust
# thrust
# thrust
# thrust
# thrust
# trush
# thrust
# thrust
# thrust
# thrust
# thrust
# thrust
# thrust
# undergoing
# undergoing
# undergoing
# undergoing
# undergoing
# undergoing
# undergoing
# undergoing
# undergoing
# undergo
# undergoing
# undergo
# underwent
# undergo
# undergoing
# undergone
# undo
# undo
# undo
# undoing
# undoing
# undoing
# undo
# undo
# undoing
# undoing
# undoing
# undoing
# undid
# undid
# undo
# undid
# upholds
# upholds
# upholds
# upholds
# upholds
# upholds
# purhled
# upholds
# upholds
# upholds
# upholds
# upholds
# unwars
# upheld
# uphold
# upheld
# upset
# upset
# upset
# upsets
# upset
# upsets
# upsetting
# upsets
# upsetting
# upsetting
# pusters
# unspetting
# upsetting
# upsets
# upset
# upsets
# awake
# awakes
# awakes
# awakes
# awakes
# awakes
# awakes
# awake
# awakes
# awakes
# awakes
# awakes
# awake
# awakes
# awakes
# awakes
# forswearing
# forswearing
# forswearing
# forswears
# forswearing
# forswears
# forswears
# forswears
# forswears
# forswearing
# forswears
# forswearing
# forswearing
# forswearing
# forswearing
# forswearing
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweave
# interweaves
# interweave
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withdraw
# withheld
# withheld
# withholds
# withholds
# withholds
# withheld
# withholds
# withholds
# withheld
# withholds
# withholds
# withhild
# withheld
# withholds
# withheld
# withheld
# withstands
# withstand
# withstands
# withstand
# withstands
# withstand
# withstands
# withstands
# withstands
# withstands
# withstands
# withstands
# withstands
# withstands
# withstands
# withstands
# hurt
# hurts
# hurt
# hurt
# hurt
# hurt
# hurt
# hurt
# hurts
# hurt
# hurt
# hurt
# hurt
# hurts
# hurt
# hurt
# begins
# beginning
# begins
# begins
# begins
# begins
# begin
# beginning
# beginning
# beginning
# beginning
# beginning
# begins
# beginning
# begins
# begins
# put
# put
# put
# puts
# put
# puts
# puts
# puts
# putting
# putting
# put
# putting
# put
# put
# put
# put
# bet
# bet
# bet
# bet
# bet
# bet
# bet
# bets
# betting
# betting
# betting
# betting
# bet
# bet
# betting
# bet
# bids
# bids
# bids
# bid
# bid
# bids
# bids
# bid
# bids
# bidding
# bidding
# kisses
# bid
# bid
# bids
# bids
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cast
# cost
# cost
# cost
# cost
# cost
# costs
# costs
# costs
# cost
# cost
# costs
# cost
# costs
# cost
# cost
# cost
# eats
# eating
# ate
# eating
# eat
# eats
# eat
# eat
# eating
# eating
# eating
# eat
# eating
# eating
# eating
# taes
# falls
# falls
# falls
# falls
# falls
# falls
# falls
# falls
# falls
# falls
# falls
# falls
# fell
# fell
# fell
# fell
# finds
# finds
# finds
# finds
# finds
# finds
# finds
# finds
# finds
# finds
# finds
# finds
# finds
# finds
# found
# finds
# bitting
# bitting
# bitting
# bit
# bitting
# bitting
# bitting
# bite
# bitting
# bitting
# bitting
# bite
# bitting
# bitting
# bitting
# bitting
# blow
# blow
# blow
# blow
# blow
# blow
# blow
# blowing
# blow
# blow
# blow
# blow
# blew
# blew
# blew
# blew
# come
# coming
# come
# come
# comes
# comes
# come
# comes
# comes
# comes
# comes
# comes
# came
# came
# came
# came
# does
# did
# doing
# dine
# dine
# did
# ding
# dinging
# dinging
# dine
# did
# dine
# did
# did
# did
# dig
# draw
# driwed
# draw
# draw
# draws
# draws
# draw
# draw
# draws
# draw
# draw
# draws
# drew
# drew
# drew
# draw
# feeds
# feed
# feeds
# feeds
# feed
# feeds
# fed
# feed
# feeding
# feeds
# feeds
# fends
# feeds
# feeds
# fed
# fed
# fights
# fights
# fights
# fights
# fight
# fights
# fight
# fights
# fight
# fights
# firms
# fights
# fought
# fights
# fights
# fight
# flies
# flies
# flies
# flies
# flies
# flies
# flies
# fly
# flies
# flies
# flies
# flies
# flew
# flew
# flew
# fly
# getting
# get
# getting
# get
# gets
# get
# get
# getting
# getting
# getting
# gets
# getting
# got
# got
# got
# got
# give
# give
# give
# give
# give
# give
# gave
# give
# give
# gives
# giving
# giving
# gave
# gave
# gave
# gave
# gonging
# going
# go
# goes
# going
# going
# going
# going
# going
# goning
# going
# going
# went
# went
# went
# went
# grow
# grow
# grow
# grow
# grow
# grow
# grow
# grow
# growing
# grow
# grow
# grow
# grew
# grow
# werging
# grow
# having
# have
# have
# have
# hides
# has
# hading
# has
# having
# having
# have
# having
# hanging
# hading
# has
# hading
# hide
# hiding
# hiding
# hid
# hiding
# hides
# hides
# hide
# hide
# hides
# hides
# hide
# hid
# hides
# hides
# hides
# hit
# hit
# hit
# hits
# hit
# hit
# hits
# hit
# hitting
# hitting
# hit
# hitting
# hit
# hit
# hit
# hits
# hold
# hold
# hold
# hold
# holding
# held
# held
# holds
# holding
# holds
# holds
# hold
# held
# hills
# held
# held
# know
# know
# know
# know
# know
# know
# knows
# knows
# knows
# knows
# know
# know
# know
# knows
# knows
# know
# lending
# lent
# lent
# lends
# lending
# lending
# lend
# lending
# lends
# lend
# lend
# lending
# lent
# lent
# lent
# lent
# leave
# leaving
# leave
# leave
# leave
# leave
# leave
# leve
# leaving
# leave
# leave
# leave
# leave
# leave
# leave
# leave
# lose
# lose
# lose
# lose
# lose
# lose
# lose
# lose
# lose
# lose
# lose
# losing
# lost
# lost
# lost
# lost
# paid
# pays
# pays
# paying
# paid
# paying
# paying
# paying
# paying
# pays
# pays
# pays
# paid
# paid
# paid
# paid
# read
# eraded
# read
# reads
# read
# reading
# reading
# reads
# reading
# reading
# reading
# reads
# read
# read
# read
# read
# ride
# ride
# ride
# rides
# rides
# riding
# rides
# ride
# riding
# rides
# rides
# rides
# ride
# ride
# ride
# rod
# ringing
# rings
# rings
# rings
# rings
# rings
# rings
# ring
# ring
# ring
# ringing
# ring
# rang
# rings
# rang
# rang
# run
# rinning
# runs
# running
# runging
# running
# runs
# run
# running
# running
# running
# running
# ran
# ranning
# rinning
# ran
# say
# say
# says
# say
# say
# said
# says
# said
# say
# said
# say
# say
# says
# said
# said
# says
# seeing
# seeing
# see
# seeing
# seing
# seeing
# seeing
# sens
# see
# see
# seeing
# seeing
# saw
# seew
# saking
# saking
# sell
# sell
# sell
# sell
# sell
# sell
# sell
# sledling
# sell
# sell
# sell
# sell
# sells
# sells
# selling
# sold
# shake
# shake
# shaking
# shake
# shake
# shakes
# shake
# shakes
# shaking
# shake
# shake
# shake
# shake
# shanking
# shake
# shank
# singing
# singing
# singing
# singing
# singing
# singing
# singing
# singing
# singing
# singing
# singing
# singing
# singing
# singing
# sang
# snag
# sit
# sit
# sit
# sitting
# sit
# sit
# sitting
# sit
# sitting
# sitting
# sitting
# sitting
# sat
# sat
# sat
# sat
# sleeping
# sleeping
# sleeps
# sleeps
# sleeps
# sleeping
# sleeps
# sleeping
# sleeping
# sleeping
# slepped
# sleeps
# sleeping
# sleeps
# sleeping
# slept
# speaks
# speaks
# speak
# speaks
# speaks
# skept
# speaks
# speaks
# speaking
# speaks
# speaks
# speaking
# speaks
# speaks
# speak
# speaks
# spent
# spends
# spends
# spends
# spent
# spent
# spends
# spends
# spends
# spent
# spends
# spends
# spends
# spends
# spent
# spent
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# stands
# teaks
# take
# take
# take
# take
# take
# take
# takking
# taking
# takking
# take
# taking
# taking
# taking
# taking
# taking
# tells
# tells
# tells
# tells
# tells
# tells
# tells
# tells
# tells
# tells
# tells
# tells
# telling
# tell
# told
# telling
# thinks
# thinking
# thinks
# thinks
# thinks
# thinking
# thinking
# thinks
# thinks
# thinks
# thinks
# thinks
# thinks
# think
# think
# thinks
# throws
# throws
# throw
# throws
# threw
# threw
# threw
# threw
# throw
# hithold
# threw
# threw
# twearing
# threw
# treal
# throws
# understands
# understands
# understands
# understands
# understands
# understanding
# understanding
# understands
# understands
# understanding
# understands
# understands
# understands
# understood
# understands
# understands
# wears
# whearing
# wears
# wears
# wear
# wears
# wears
# wears
# wears
# wears
# wears
# wears
# wearing
# wering
# wearing
# wearing
# winning
# winning
# wins
# wins
# win
# wins
# wins
# winning
# winning
# winning
# winning
# winning
# winning
# winning
# winning
# winning
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# writes
# inlays
# inlays
# inlays
# inlay
# inlays
# inlaying
# inlay
# inlays
# inlaining
# inlaid
# inlay
# inlaid
# inlain
# inlay
# inlay
# inlaid
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# grave
# gainsay
# gainsay
# gainsays
# gainsays
# gainsays
# gainsays
# gainsays
# gainsays
# gainsays
# gainsay
# gainsay
# gainsay
# gainsaid
# gainsay
# gainsaid
# gainsaid
# freeze
# freezes
# freezes
# freezes
# freezes
# freezes
# freeze
# freezes
# freeze
# freeze
# freezes
# freezes
# freezing
# freezing
# freezing
# freezing
# forsake
# forsake
# forsake
# forsake
# forsake
# forsake
# forsake
# forsaking
# forsaking
# forsaking
# forsake
# forsake
# forsaking
# forsaking
# forsaking
# forsaking
# forego
# forget
# forego
# foregoing
# forego
# foregoing
# foregoing
# foregoing
# foregoing
# foregoing
# foregoing
# foregoing
# foregoes
# foregon
# foregored
# foregoes
# foredo
# foredid
# foredo
# foredid
# foredo
# foredo
# foredo
# foredo
# foredo
# foredoing
# foredoing
# foredid
# foredid
# foredid
# foredid
# foredid
# cling
# clings
# cling
# clings
# clinging
# clings
# clings
# clings
# clinging
# clinging
# clinging
# clinging
# clings
# clings
# clings
# clung
# cleaves
# cleaves
# clave
# cleaves
# cleaves
# cleaves
# cleaves
# cleaves
# cleaves
# cleaves
# cleaves
# cleaves
# clave
# clave
# cleaving
# clave
# chide
# chide
# chides
# chides
# chides
# chides
# chides
# chide
# chides
# chiding
# chides
# chides
# chides
# chides
# chides
# chides
# bestride
# bestride
# bestirs
# bestride
# bestride
# bestride
# bestride
# bestride
# bestride
# bestrides
# bestride
# bestride
# bestride
# bestrides
# bestride
# bestride
# bereaves
# bereave
# bereaves
# bereaves
# bereave
# bereaves
# bereave
# bereave
# bereaves
# bereaves
# bereaves
# bereaves
# bereft
# bereft
# bereave
# bereave
# misgave
# misgiving
# misgive
# misgive
# misgave
# misgave
# misgave
# misgive
# misgave
# misgave
# misgave
# misgave
# misgave
# misgave
# misgave
# misgave
# misdealt
# misdeal
# misdealt
# misdealt
# misdealt
# misdeal
# misdealt
# misdealt
# misdeal
# misdealt
# misdealt
# misdealt
# misdealt
# misdeal
# misdealt
# misdealt
# showing
# showing
# showed
# show
# showing
# showing
# showing
# showing
# showing
# show
# show
# showing
# showing
# showing
# show
# showing
# underlies
# underlies
# underlies
# underlies
# underlies
# underlies
# underlie
# underlies
# underlies
# underlies
# underlies
# underlies
# underlie
# underlie
# underlie
# underlies
# tread
# treads
# treading
# treads
# tread
# tread
# treading
# treading
# treads
# treads
# treading
# treading
# treads
# trod
# tread
# tread
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# stride
# measures
# measures
# measure
# measures
# measures
# measure
# measure
# measure
# measure
# measures
# measure
# measure
# measures
# measures
# measures
# measures
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# flame
# fixes
# fixing
# fix
# fix
# fixes
# fixes
# fixes
# fixing
# fixes
# fixing
# fixing
# fix
# fixing
# fixes
# fixing
# fixes
# firm
# firmed
# firming
# firms
# firm
# firms
# firmed
# firms
# firms
# firming
# firming
# firming
# firmed
# firming
# firming
# firming
# fidgets
# fidget
# fidgets
# fidget
# fidgets
# fidget
# fidgets
# fidget
# fignted
# fidgets
# fidget
# fidgeting
# fidgets
# fidgets
# fidget
# fidget
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# fictionalize
# ferry
# ferries
# ferry
# ferries
# ferry
# ferry
# ferries
# ferries
# ferries
# ferries
# ferries
# ferries
# ferry
# ferries
# ferries
# ferries
# fertilizes
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilize
# fertilizes
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flake
# flails
# flail
# flails
# flails
# flail
# flails
# flailing
# flails
# flailing
# flail
# flailed
# flailing
# flail
# flail
# flail
# flail
# finalizes
# finalize
# finalizes
# finalize
# finalize
# finalize
# finalize
# finalize
# finalize
# finalize
# finalize
# finalize
# finalize
# finalize
# finalize
# finalize
# figure
# figure
# figure
# figure
# figure
# figure
# figures
# figures
# figure
# figure
# figures
# figures
# figure
# figure
# figure
# figures
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# filches
# fetter
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# fetters
# festoon
# festoon
# festooning
# festoon
# festoon
# festoon
# festoon
# festoon
# festoon
# festoon
# festoon
# festoon
# festoon
# festoon
# festoon
# festoon
# festers
# festers
# festers
# festers
# festers
# festers
# festers
# festers
# festers
# festers
# festering
# festers
# festers
# festers
# festers
# festers
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferments
# ferment
# ferments
# feints
# feints
# feints
# feints
# feints
# feint
# feinting
# feint
# feints
# feints
# feints
# feints
# feints
# feints
# feints
# feints
# feigns
# feigns
# feigns
# feigns
# feigns
# feigns
# feigns
# feigns
# feigns
# feigns
# feign
# feigns
# feign
# feign
# feigns
# feigns
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# federates
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fazes
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# fattens
# expiates
# expiates
# expiates
# expiates
# expiated
# expiates
# expiates
# expiates
# expiated
# expiates
# expiates
# expiates
# expiates
# expiated
# expiated
# expiates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exonerates
# exited
# exits
# exited
# exited
# exits
# exited
# exiting
# exited
# exited
# exiting
# exited
# exited
# exited
# exited
# exited
# exits
# exists
# exists
# exists
# exists
# exists
# exists
# exist
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exists
# exiles
# exile
# exiled
# exiled
# exiled
# exiles
# exiles
# exiles
# exiles
# exile
# exiling
# exiled
# exiles
# exiled
# exiled
# exiled
# exhorts
# exhorts
# exhorts
# exhorts
# exhorts
# ehtoring
# exhorts
# exhorts
# exhorts
# exhorts
# exhorts
# exhorts
# exhorts
# exhorts
# exhorts
# exhorts
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exhilarates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpates
# exculpate
# exculpates
# exculpates
# exculpates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exasperates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# exacerbates
# Gaussian score: 0.00
# ==============================
# input:  abandon
# target: abet
# pred:   abandons
# ==============================
# input:  abandoned
# target: abetting
# pred:   abet
# BLEU score: 0.21
